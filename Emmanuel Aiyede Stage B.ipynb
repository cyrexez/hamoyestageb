# %%
import pandas as pd
df=pd.read_csv('energydata_complete .csv')

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# Read the dataset into a pandas DataFrame called df
# ...

# Remove columns "date" and "lights"
df = df.drop(["date", "lights"], axis=1)

# Separate the target variable
target = df["Appliances"]
features = df.drop("Appliances", axis=1)

# Normalize the dataset using MinMaxScaler
scaler = MinMaxScaler()
features_scaled = scaler.fit_transform(features)
target_scaled = scaler.fit_transform(target.values.reshape(-1,1))

# Split the dataset into a 70-30 train-test split
X_train, X_test, y_train, y_test = train_test_split(
    features_scaled, target_scaled, test_size=0.3, random_state=42
)

# Train a ridge regression model with alpha=0.4
ridge_model = Ridge(alpha=0.4)
ridge_model.fit(X_train, y_train)

# Predict on the test set
y_pred = ridge_model.predict(X_test)


# Calculate Root Mean Squared Error (RMSE)
rmse = round(mean_squared_error(y_test, y_pred, squared=False), 3)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Root Mean Squared Error (RMSE): 0.088

# %%
from sklearn.linear_model import LinearRegression
X = df['T2'].values.reshape(-1, 1)  # Reshape to a 2D array as expected by scikit-learn
y = df['T6'].values.reshape(-1, 1)

# Creating a LinearRegression model
model = LinearRegression()

# Fitting the linear model
model.fit(X, y)

# Calculating the R-squared value
r_squared = round(model.score(X, y),2)

# Printing the R-squared value
print("R-squared value:", r_squared)
# Out:
# R-squared value: 0.64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# Read the dataset into a pandas DataFrame called df
# ...

# Remove columns "date" and "lights"
df = df.drop(["date", "lights"], axis=1)

# Separate the target variable
target = df["Appliances"]
features = df.drop("Appliances", axis=1)

# Normalize the dataset using MinMaxScaler
scaler = MinMaxScaler()
features_scaled = scaler.fit_transform(features)
target_scaled = scaler.fit_transform(target.values.reshape(-1, 1))

# Split the dataset into a 70-30 train-test split
X_train, X_test, y_train, y_test = train_test_split(
    features_scaled, target_scaled, test_size=0.3, random_state=42
)

# Train a multiple linear regression model
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)

# Train a Lasso regression model with alpha=0.001
lasso_model = Lasso(alpha=0.001)
lasso_model.fit(X_train, y_train)

# Get the feature weights from the Lasso regression model
feature_weights = lasso_model.coef_

# Count the number of features with non-zero feature weights
num_non_zero_features = sum(feature_weights != 0)

# Predict on the test set using the Lasso regression model
y_pred = lasso_model.predict(X_test)

# Calculate the Root Mean Squared Error (RMSE)
rmse = round(mean_squared_error(y_test, y_pred, squared=False), 3)

print("Number of features with non-zero feature weights:", num_non_zero_features)
print("New RMSE with Lasso regression:", rmse)
# Out:
# Number of features with non-zero feature weights: 4
# New RMSE with Lasso regression: 0.094

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Read the dataset into a pandas DataFrame called df
# ...

# Remove columns "date" and "lights"
df = df.drop(["date", "lights"], axis=1)

# Separate the target variable
target = df["Appliances"]
features = df.drop("Appliances", axis=1)

# Normalize the dataset using MinMaxScaler
scaler = MinMaxScaler()
features_scaled = scaler.fit_transform(features)
target_scaled = scaler.fit_transform(target.values.reshape(-1,1))

# Split the dataset into a 70-30 train-test split
X_train, X_test, y_train, y_test = train_test_split(
    features_scaled, target_scaled, test_size=0.3, random_state=42
)

# Fit a multiple linear regression model on the training set
model = LinearRegression()
model.fit(X_train, y_train)

# Get the feature weights
feature_weights = model.coef_[0]

# Create a DataFrame to display the feature weights
feature_weights_df = pd.DataFrame({"Feature": features.columns, "Weight": feature_weights})
feature_weights_df = feature_weights_df.sort_values("Weight", ascending=True)

# Print the features with the lowest and highest weights
lowest_weight_feature = feature_weights_df.iloc[0]
highest_weight_feature = feature_weights_df.iloc[-1]

print("Feature with the lowest weight:", lowest_weight_feature["Feature"])
print("Feature with the highest weight:", highest_weight_feature["Feature"])
# Out:
# Feature with the lowest weight: RH_2
# Feature with the highest weight: RH_1
